# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df =  pd.read_csv("FMCG Raw Sales Data.csv")

# %%
df
# Out:
#          Month      Channel Sub-Channels                  Product Name  \
# 0    01-Dec-20  Marketplace       AMAZON         ALOE + AMLA JUICE 1 L
# 1    01-Dec-20  Marketplace       AMAZON     ALOE + GARCINIA JUICE 1 L
# 2    01-Dec-20  Marketplace       AMAZON           ALOE VERA JUICE 1 L
# 3    01-Dec-20  Marketplace       AMAZON     ALOE VERA SKIN GEL 500 GM
# 4    01-Dec-20  Marketplace       AMAZON                NEEM JUICE 1 L
# ..         ...          ...          ...                           ...
# 219  01-Mar-21  Marketplace   Big Basket      ORGANIC GULKAND 300grams
# 220  01-Mar-21  Marketplace     Flipkart     ALOE + GARCINIA JUICE 1 L
# 221  01-Mar-21  Marketplace     Flipkart                AMLA JUICE 1 L
# 222  01-Mar-21  Marketplace     Flipkart            GET SLIM JUICE 1 L
# 223  01-Mar-21  Marketplace        GOQII  RAW HONEY ( MADHU) 500 GRAMS
#
#               Category      Qty        Sales
# 0               Juices   1,116     4,28,700
# ...

# %%
df["month"] = df["Month"].apply(lambda x : x[x.index("-")+1:-3])

# %%
df
# Out:
#          Month      Channel Sub-Channels                  Product Name  \
# 0    01-Dec-20  Marketplace       AMAZON         ALOE + AMLA JUICE 1 L
# 1    01-Dec-20  Marketplace       AMAZON     ALOE + GARCINIA JUICE 1 L
# 2    01-Dec-20  Marketplace       AMAZON           ALOE VERA JUICE 1 L
# 3    01-Dec-20  Marketplace       AMAZON     ALOE VERA SKIN GEL 500 GM
# 4    01-Dec-20  Marketplace       AMAZON                NEEM JUICE 1 L
# ..         ...          ...          ...                           ...
# 219  01-Mar-21  Marketplace   Big Basket      ORGANIC GULKAND 300grams
# 220  01-Mar-21  Marketplace     Flipkart     ALOE + GARCINIA JUICE 1 L
# 221  01-Mar-21  Marketplace     Flipkart                AMLA JUICE 1 L
# 222  01-Mar-21  Marketplace     Flipkart            GET SLIM JUICE 1 L
# 223  01-Mar-21  Marketplace        GOQII  RAW HONEY ( MADHU) 500 GRAMS
#
#               Category   Qty    Sales month               products
# ...

# %%
def clean_amount(amount):
    
    return int(amount.replace(",",""))

# %%
df["Qty"] = df["Qty"].apply(clean_amount)
df["Sales"] = df["Sales"].apply(clean_amount)

# %%
df.groupby("Category")["Qty"].sum()
# Out:
# Category
# Functional nutrition     42354
# Gourmet Nutrition        89279
# Juices                  178148
# Name: Qty, dtype: int64

# %%
df.groupby("Sub-Channels")["Sales"].sum()
# Out:
# Sub-Channels
# AMAZON               35606804
# Big Basket            1207522
# D2C                  28047538
# Flipkart              3770415
# GOQII                  582600
# Offline - Central      375332
# Offline - East         811146
# Offline - MT          6257948
# Offline - South       3446395
# Offline - West        6441427
# Offline -North        1206564
# Name: Sales, dtype: int64

# %%
df[df["Sales"] == df["Sales"].max()]["month"]
# Out:
# 168    Mar
# Name: month, dtype: object

# %%
def clean(prdct):
    for i in prdct:
        if i.isdigit()==True:
           return prdct[:prdct.index(i)].strip()

# %%
df["products"] =  df["Product Name"].apply(clean)

# %%
df

# %%
pd.DataFrame(df["products"].unique())
# Out:
#                                  0
# 0                ALOE + AMLA JUICE
# 1            ALOE + GARCINIA JUICE
# 2                  ALOE VERA JUICE
# 3               ALOE VERA SKIN GEL
# 4                       NEEM JUICE
# 5                       NONI JUICE
# 6           SLIM SHAKE - CHOCOLATE
# 7               SLIM SHAKE - MANGO
# 8                   TRIPHALA JUICE
# 9                TULSI GILOY JUICE
# 10               WHEAT GRASS JUICE
# 11                      AMLA JUICE
# 12                  GET SLIM JUICE
# 13                    HIMALAYA OIL
# 14                 VIGOR MAX JUICE
# 15          ORGANIC JAGGERY POWDER
# 16             APPLE CIDER VINEGAR
# 17              VIRGIN COCONUT OIL
# 18              KARELA JAMUN JUICE
# 19    MASALA SUPERGRAIN MIX ENERGY
# 20  MASALA SUPERGRAIN MIX IMMUNITY
# 21              AMLA + GILOY JUICE
# 22                  DIA FREE JUICE
# 23               IMMUNE CARE JUICE
# 24                 ORGANIC GULKAND
# 25       VEGAN PROTEIN - CHOCOLATE
# ...

# %%
df[df["Sales"]==df["Sales"].max()]["products"]
# Out:
# 138    APPLE CIDER VINEGAR
# Name: products, dtype: object

# %%
with pd.ExcelWriter("project3.xlsx",engine = "openpyxl") as writer :
    df.to_excel(writer , sheet_name = "month name" , index = False  )
    (df.groupby("month")["Qty"].sum()).to_excel(writer,sheet_name = "monthwise sum of Qty")
    df.groupby("Category")["Qty"].sum().to_excel(writer,sheet_name = "category wise sum of Qty")
    df[df["Sales"] == df["Sales"].max()]["month"].to_excel(writer,sheet_name = " highest sales month")
    df[df["Sales"]==df["Sales"].max()]["products"].to_excel(writer,sheet_name = "highest saling product")
    df.to_excel(writer,sheet_name= "clean product name",index = False)
    pd.DataFrame(df["products"].unique()).to_excel(writer, sheet_name ="unique product name")
    df.groupby("Sub-Channels")["Sales"].sum().to_excel(writer,sheet_name="sub-channel wise total sales")
